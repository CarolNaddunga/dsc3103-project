# %% [markdown]
# ## Lab 1
#
# In this lab you will use the dataset provided under week one activity.
# Perform tasks A to D by following the procedures below;
#
# **Setup:**
#  Initialize your Git repository using the standard project structure:
# ```
# dsc3103-project/
# ├── README.md
# ├── requirements.txt
# ├── data/
# │   ├── raw/
# │   ├── interim/
# │   └── processed/
# ├── src/
# ├── tests/
# ├── notebooks/
# └── docs/
# ```
#
# **Part A — Acquire, don't touch.**
# Obtain the raw dataset provided and place it, completely unmodified, in `data/raw/`. Commit it to Git with a clear message (e.g., `"Added raw data, unmodified, as received"`).
#
# **Part B — Classify it.**
# In a short markdown note (`docs/data_source.md`), answer:
# - Is this structured, semi-structured, or unstructured data? Justify your answer.
# - List every variable (column) and what it represents.
# - Which variable would be the **target**, and which would be candidate **features**?
#
# **Part C — Load it, look at it, don't fix it.**
# In a notebook or script, load the raw file (`pandas.read_csv` or equivalent) and run only *inspection* commands — `.head()`, `.info()`, `.describe()`, `.dtypes`, row count. Do not modify the DataFrame or write anything back to `data/raw/`.
#
# **Part D — Write down what looks wrong.**
# Based only on what you observed in Part C, list at least **five specific things that look suspicious** — a column with an implausible number of missing values, a price of zero or negative, a date that can't be right, an unexpected category, duplicate-looking rows, and so on. Write these in `docs/issues_observed.md` as a plain list — no code, no fixes. This becomes the input to next week's formal profiling and cleaning.
#
# **Deliverable:** initialized Git repository with the correct structure, the raw file committed unmodified, `docs/data_source.md`, and `docs/issues_observed.md`.
#
# **Be ready to present your work and answer verbally:**
# - Why does the raw file need to stay untouched even though you can already see problems in it?
# - Which of the "suspicious" things you listed do you think are genuine data errors, and which might just be unusual-but-valid values?

# %% [markdown]
# Structured
#
# item - represents the items that the objective is attaining.
# quantity - Represents the amount of the item the objective is getting.
# Price per unit - represents the prices of each item in relation to the quantity taken.
# total spent - represents the total amount paid for all the quantities in total for the objective.
# payment  method - represents the means for paying eg credit card or cash
# location - represents the location where the meal will be had from either takeaway or inside the store
# Transaction date - represents the date when the transaction happened.
#
# the target variable - total spent
# feature variables  - price  per unit , Quantity, item, location, Transaction date

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/dirty_cafe_sales.csv')

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  str
#  1   Item              9667 non-null   str
#  2   Quantity          9862 non-null   str
#  3   Price Per Unit    9821 non-null   str
#  4   Total Spent       9827 non-null   str
#  5   Payment Method    7421 non-null   str
#  6   Location          6735 non-null   str
#  7   Transaction Date  9841 non-null   str
# dtypes: str(8)
# memory usage: 625.1 KB

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df.describe(include='all')
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
df.dtypes
# Out:
# Transaction ID      str
# Item                str
# Quantity            str
# Price Per Unit      str
# Total Spent         str
# Payment Method      str
# Location            str
# Transaction Date    str
# dtype: object

# %%
df.shape
# Out:
# (10000, 8)

# %%
print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
# Out:
# Rows: 10000, Columns: 8

# %% [markdown]
# part d
